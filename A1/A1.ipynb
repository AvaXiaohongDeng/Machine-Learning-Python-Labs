# %% [markdown]
# ### <p style="text-align:center;">A1: Understanding and Preparing Data in Machine Learning</p>
#
# **Task 1: Data Importing**
#
# 1.1 Import the attached Social Media Sentiments Analysis Dataset stored in the file sentimentdataset.csv

# %%
#Collect data by loading a CSV file from the current working directory
import pandas as pd 
sentiment = pd.read_csv("sentimentdataset.csv")

# %% [markdown]
# 1.2 Perform a preliminary analysis: display the first 10 rows and display the column's names and their data types

# %%
#Explore data by displaying the first 10 rows
sentiment.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
# 5             5           5
# 6             6           6
# 7             7           7
# 8             8           8
# 9             9           9
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...          NaN
# 5   Feeling grateful for the little things in lif...   Positive
# 6   Rainy days call for cozy blankets and hot coc...   Positive
# 7   The new movie release is a must-watch!       ...   Positive
# ...

# %%
#Explore the data by displaying the column's names and their data types using info() or dtypes.
sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     729 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    int64
#  9   Likes         727 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 85.9+ KB

# %% [markdown]
# **<span style="color:blue;">Observations from sentiment.info():</span>**
#
# sentiment DataFrame consists of 732 entries and 15 columns. The key observations are as follows:
# - The "Sentiment" column has 729 non-null entries, indicating the presence of 3 missing values. Additionally, its data type is object, indicating that it contains categorical values.
# - The "Likes" column has 727 non-null entries, indicating the presence of 5 missing values. Additionally, its data type is float64, indicating that it contains numerical values.

# %% [markdown]
# 1.3 Imports the iris dataset from the url http://mahmouel.dev.fast.sheridanc.on.ca/iris.csv

# %%
#Collect data by loading a CSV file from the url http://mahmouel.dev.fast.sheridanc.on.ca/iris.csv
url = "http://mahmouel.dev.fast.sheridanc.on.ca/iris.csv"
iris = pd.read_csv(url)

# %% [markdown]
# 1.4 Perform a preliminary analysis: display the last 10 rows and display the column's names and their data types

# %%
#Explore data by displaying the first 10 rows
iris.head(10)
# Out:
#    Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0           0                 5.1                3.5                 1.4
# 1           1                 4.9                3.0                 1.4
# 2           2                 4.7                3.2                 NaN
# 3           3                 4.6                3.1                 1.5
# 4           4                 5.0                3.6                 1.4
# 5           5                 5.4                3.9                 1.7
# 6           6                 4.6                3.4                 1.4
# 7           7                 5.0                3.4                 1.5
# 8           8                 4.4                2.9                 1.4
# 9           9                 4.9                3.1                 1.5
#
#    petal_width_in_cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# ...

# %%
#Explore the data by displaying the column's names and their data types using info() or dtypes.
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          150 non-null    int64
#  1   sepal_length_in_cm  147 non-null    float64
#  2   sepal_width_in_cm   149 non-null    float64
#  3   petal_length_in_cm  148 non-null    float64
#  4   petal_width_in_cm   149 non-null    float64
#  5   class               147 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# **<span style="color:blue;">Observations from iris.info():</span>**
#
# iris DataFrame consists of 150 entries and 6 columns. The key observations are as follows:
#
# - The "sepal_length_in_cm" column has 147 non-null entries, indicating the presence of 3 missing values. Additionally, its data type is float64, indicating that it contains numerical values.
# - The "sepal_width_in_cm" column has 149 non-null entries, indicating the presence of 1 missing value. Additionally, its data type is float64, indicating that it contains numerical values.
# - The "petal_length_in_cm" column has 148 non-null entries, indicating the presence of 2 missing values. Additionally, its data type is float64, indicating that it contains numerical values.
# - The "petal_width_in_cm" column has 149 non-null entries, indicating the presence of 1 missing value. Additionally, its data type is float64, indicating that it contains numerical values.
# - The "class" column has 147 non-null entries, indicating the presence of 3 missing values. Additionally, its data type is object, indicating that it contains categorical values.

# %% [markdown]
# **Task 2: Understanding the Data**
#
# 2.1 Generate summary statistics of the Social Media Sentiments Analysis dataset.

# %%
#Display the summary statistics 
sentiment.describe(include='all')
# Out:
#         Unnamed: 0.1  Unnamed: 0  \
# count     732.000000  732.000000
# unique           NaN         NaN
# top              NaN         NaN
# freq             NaN         NaN
# mean      366.464481  369.740437
# std       211.513936  212.428936
# min         0.000000    0.000000
# 25%       183.750000  185.750000
# 50%       366.500000  370.500000
# 75%       549.250000  553.250000
# max       732.000000  736.000000
#
#                                                      Text    Sentiment  \
# count                                                 732          729
# unique                                                707          279
# top      A compassionate rain, tears of empathy fallin...   Positive
# freq                                                    3           43
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# ...

# %% [markdown]
# **<span style="color:blue;">Observations from sentiment.describe():</span>**
# - The "Sentiment", "Likes" columns have counts less than 732, indicating the presence of missing values in these columns.
# - "Text" column has 707 unique entries, indicating that there are some repeated values. The most frequent text is "A compassionate rain, tears of empathy falling..." with a frequency of 3.
# - "Sentiment" column has 279 unique entries, indicating that there are some repeated values. The most frequent sentiment is "Positive" with a frequency of 43.
# - "User" columns have 685 unique entries, indicating multiple users. The most frequent user is "WindWhisperer" with a frequency of 3.
# - "Platform" columns have 4 unique entries, indicating there are 4 platforms. The most frequent platform is "Instagram" with a frequency of 258.
# - "Hashtags" column has 697 unique entries, indicating that there are some repeated values.
# - "Country" column has 115 unique entries, indicating diversity in the countries. The most frequent country is the USA with a frequency of 59.

# %% [markdown]
# 2.2 Generate summary statistics of the Iris dataset.

# %%
#Display the summary statistics
iris.describe(include="all")
# Out:
#         Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# count   150.000000          147.000000         149.000000          148.000000
# unique         NaN                 NaN                NaN                 NaN
# top            NaN                 NaN                NaN                 NaN
# freq           NaN                 NaN                NaN                 NaN
# mean     74.500000            5.841497           3.055034            3.770270
# std      43.445368            0.830155           0.434871            1.763672
# min       0.000000            4.300000           2.000000            1.000000
# 25%      37.250000            5.100000           2.800000            1.600000
# 50%      74.500000            5.800000           3.000000            4.350000
# 75%     111.750000            6.400000           3.300000            5.100000
# max     149.000000            7.900000           4.400000            6.900000
#
# ...

# %% [markdown]
# **<span style="color:blue;">Observations from iris.describe():</span>**
# - The "sepal_length_in_cm," "sepal_width_in_cm," "petal_length_in_cm,", "petal_width_in_cm" and "class" columns have counts less than 150, indicating the presence of missing values in these columns.
# - "class" column has missing data. It has 3 unique values, indicating there is three types of iris class.Moreover, the most frequent class is "Iris-versicolor" with a frequency of 50.

# %% [markdown]
# 2.3 Identify missing values in each column of the Social Media Sentiments Analysis dataset

# %%
# Display the rows with null values
sentiment[sentiment.isnull().any(axis=1)]
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 3              3           3
# 4              4           4
# 8              8           8
# 19            19          19
# 23            23          23
# 40            41          42
# 57            58          60
#
#                                                  Text       Sentiment  \
# 3    Excited about the upcoming weekend getaway!  ...      Positive
# 4    Trying out a new recipe for dinner tonight.  ...             NaN
# 8    Political discussions heating up on the timel...             NaN
# 19   Winter blues got me feeling low.             ...      Negative
# 23   Just finished a challenging workout routine. ...             NaN
# 40   Planning a garden makeover for spring.       ...      Positive
# 57   Laughter is the best medicine—enjoying a come...   Joy
#
#            Timestamp               User     Platform  \
# 3   2023-01-15 18:20      AdventureX       Facebook
# 4   2023-01-15 19:55      ChefCook        Instagram
# ...

# %% [markdown]
# **<span style="color:blue;">Observations from sentiment.isnull():</span>**
# - "Likes" column has missing data in rows with index 3, 19, 23, 40, and 57.
# - "Sentiment" column has missing data in rows with index 4, 8 and 23 in the sentiment DataFrame.

# %% [markdown]
# 2.4 Identify missing values in each column of the Iris dataset if exist.

# %%
# Display the rows with null values
iris[iris.isnull().any(axis=1)]
# Out:
#      Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 2             2                 4.7                3.2                 NaN
# 6             6                 4.6                3.4                 1.4
# 13           13                 4.3                3.0                 1.1
# 18           18                 NaN                3.8                 1.7
# 59           59                 NaN                2.7                 3.9
# 103         103                 6.3                NaN                 5.6
# 106         106                 4.9                2.5                 NaN
# 125         125                 7.2                3.2                 6.0
# 139         139                 NaN                3.1                 5.4
# 147         147                 6.5                3.0                 5.2
#
#      petal_width_in_cm            class
# 2                  0.2      Iris-setosa
# 6                  0.3              NaN
# ...

# %% [markdown]
# **<span style="color:blue;">Observations from iris.isnull():</span>**
# - "sepal_length_in_cm," column has missing data in rows with index 18, 59, and 139.
# - "sepal_width_in_cm," column has missing data in rows with index 103.
# - "petal_length_in_cm," column has missing data in rows with index 2 and 106.
# - "petal_width_in_cm" column has missing data in rows with index 13.
# - "class" column has missing data in rows with index 6, 125 and 147.

# %% [markdown]
# 2.5 Visualize the distribution of classes in the iris dataset (target column).
#
# Count plot: It is used to visualize the distribution of class column as class column is categorical column. It displays the frequency or count of each category.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

#Visualize the distribution of class column
plt.figure(figsize=(10, 5))
sns.countplot(iris, x='class')
plt.title('Distribution of class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 2.6 Visualize the distribution of classes in Social Media Sentiments Analysis (Sentiment column).

# %%
#Visualize the distribution of Sentiment column
plt.figure(figsize=(10, 5))
sns.countplot(sentiment, x='Sentiment')
plt.title('Distribution of Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Task 3: Handling Missing Data**
#
# 3.1 Choose an appropriate strategy to handle missing data in the two datasets provided.
#
# 1. sentiment dataFrame
#
# There are two columns with missing data based on the previous observation. To address these missing values and minimize their impact on the subsequent analysis, the following solutions are proposed:
#
#     - For the "Sentiment" column, where the percentage of missing values is small (0.4%) and the dataset size is substantial, removal will be applied.
#
#     - For the "Likes" column, where the percentage of missing values is small (0.7%) and the dataset size is substantial, removal will be applied.
#
# 2. iris dataFrame
#
# There are five columns with missing data based on the previous observation. To address these missing values and minimize their impact on the subsequent analysis, the following solutions are proposed:
#
#     - For columns ("sepal_length_in_cm," "sepal_width_in_cm," "petal_length_in_cm," "petal_width_in_cm"), median imputation will be applied, considering the limited dataset size (150 entries).
#
#     - For the "class" column, which is categorical, mode imputation will be applied due to its limited dataset size.

# %% [markdown]
# 3.2 Implement the chosen strategy using appropriate Python packages.

# %%
#Remove missing data in sentiment dataFrame
sentiment = sentiment.dropna()
sentiment.info()  #Check if missing datas has been removed.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 725 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  725 non-null    int64
#  1   Unnamed: 0    725 non-null    int64
#  2   Text          725 non-null    object
#  3   Sentiment     725 non-null    object
#  4   Timestamp     725 non-null    object
#  5   User          725 non-null    object
#  6   Platform      725 non-null    object
#  7   Hashtags      725 non-null    object
#  8   Retweets      725 non-null    int64
#  9   Likes         725 non-null    float64
#  10  Country       725 non-null    object
#  11  Year          725 non-null    int64
#  12  Month         725 non-null    int64
#  13  Day           725 non-null    int64
#  14  Hour          725 non-null    int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 90.6+ KB

# %%
#Implement median imputation for missing data of the "sepal_length_in_cm" column.
iris['sepal_length_in_cm'] = iris['sepal_length_in_cm'].fillna(iris['sepal_length_in_cm'].median())

#Implement median imputation for missing data of the "sepal_width_in_cm" column.
iris['sepal_width_in_cm'] = iris['sepal_width_in_cm'].fillna(iris['sepal_width_in_cm'].median())

#Implement median imputation for missing data of the "petal_length_in_cm" column.
iris['petal_length_in_cm'] = iris['petal_length_in_cm'].fillna(iris['petal_length_in_cm'].median())

#Implement median imputation for missing data of the "petal_width_in_cm" column.
iris['petal_width_in_cm'] = iris['petal_width_in_cm'].fillna(iris['petal_width_in_cm'].median())
   
#Implement mode imputation for missing data of the "class" column
iris['class'] = iris['class'].fillna(iris['class'].mode().iloc[0])

iris[iris['Unnamed: 0'] ==18]  #Check if missing data has been handled
# Out:
#     Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 18          18                 5.8                3.8                 1.7
#
#     petal_width_in_cm        class
# 18                0.3  Iris-setosa

# %% [markdown]
# **Task 4: Data Normalization**
#
# 4.1 Explain why normalization is important in machine learning.
#
# Normalization is crucial in machine learning for the following reasons:
#
# * Some models achieve better performance when features are on a similar scale, facilitating faster algorithm convergence.
# * Normalization ensures that all features contribute equally to the model, preventing dominance by those with larger magnitudes.
# * Normalization addresses sensitivity issues in algorithms like k-nearest neighbors and support vector machines, which are influenced by the scale of input features.

# %% [markdown]
# 4.2 Normalize the features in the two datasets using an appropriate technique using Python
#
# **For sentiment dataFrame**
#
# 1. Visualize the distribution of each numerical column using a histogram to assess its normality. Observe if the distribution resembles a bell curve, which is indicative of a Gaussian distribution.

# %%
#Visualize the distribution of each numerical column in sentiment dataFrame
numeric_columns = sentiment.select_dtypes(include=['float64', 'int64'])

numeric_columns.hist(bins=20, figsize=(9, 6))
plt.suptitle('Histograms for Numerical Columns in sentiment DataFrame', y=0.95)
plt.show()

# %% [markdown]
# 2. Proceed to normalize the features based on the observed distribution
#
# - Z-Score Normalization will be applied for columns "Retweets", "Likes", and "Hour" as they are approximately Gaussian.
# - Min-Max Normalization will be applied for columns "Unnamed: 0.1", "Unnamed: 0", "Year", "Month", and "Day" as they are non-Gaussian.

# %%
#z-score Normalization in sentiment dataFrame
from sklearn.preprocessing import StandardScaler 
z_numerical_columns = ['Retweets', 'Likes', 'Hour']
sentiment[z_numerical_columns] = StandardScaler().fit_transform(sentiment[z_numerical_columns])

#min-max Normalization in sentiment dataFrame
from sklearn.preprocessing import MinMaxScaler
m_numerical_columns = ['Unnamed: 0.1', 'Unnamed: 0', 'Year', 'Month', 'Day']
sentiment[m_numerical_columns] = MinMaxScaler().fit_transform(sentiment[m_numerical_columns])
sentiment.head(2)  #Check if numerical columns have been normalized in sentiment dataFrame
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0      0.000000    0.000000
# 1      0.001366    0.001359
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
#
#           Timestamp            User    Platform  \
# 0  2023-01-15 12:30   User123         Twitter
# 1   2023-01-15 8:45   CommuterX       Twitter
#
#                                      Hashtags  Retweets     Likes     Country  \
# 0   #Nature #Park                             -0.929807 -0.923956   USA
# 1   #Traffic #Morning                         -2.350781 -2.348601   Canada
#
#    Year  Month       Day      Hour
# 0   1.0    0.0  0.466667 -0.859491
# 1   1.0    0.0  0.466667 -1.833134

# %% [markdown]
# **For iris dataFrame**
#
# 1. Visualize the distribution of each numerical column using a histogram to assess its normality. Observe if the distribution resembles a bell curve, which is indicative of a Gaussian distribution.

# %%
#Visualize the distribution of each numerical column in iris dataFrame
numeric_columns = iris.select_dtypes(include=['float64', 'int64'])

numeric_columns.hist(bins=20, figsize=(9, 6))
plt.suptitle('Histograms for Numerical Columns in iris DataFrame', y=0.95)
plt.show()

# %% [markdown]
# 2. Proceed to normalize the features based on the observed distribution
#
# - Z-Score Normalization will be applied for columns "sepal_length_in_cm" and "sepal_width_in_cm" as they are approximately Gaussian.
# - Min-Max Normalization will be applied for columns "Unnamed: 0", "petal_length_in_cm", and "petal_width_in_cm" as they are non-Gaussian.

# %%
#z-score Normalization in iris dataFrame
z_numerical_columns = ['sepal_length_in_cm', 'sepal_width_in_cm']
iris[z_numerical_columns] = StandardScaler().fit_transform(iris[z_numerical_columns])

#min-max Normalization in iris dataFrame
m_numerical_columns = ['Unnamed: 0', 'petal_length_in_cm', 'petal_width_in_cm']
iris[m_numerical_columns] = MinMaxScaler().fit_transform(iris[m_numerical_columns])
iris.head(2)  #Check if numerical columns have been normalized in iris dataFrame
# Out:
#    Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0    0.000000           -0.904320           1.030899            0.067797
# 1    0.006711           -1.148511          -0.126547            0.067797
#
#    petal_width_in_cm        class
# 0           0.041667  Iris-setosa
# 1           0.041667  Iris-setosa

# %% [markdown]
# **Task 5: Addressing Class Imbalance**
#
# 5.1 Discuss why class imbalance can be a problem in machine learning models.
#
# Class imbalance can be a problem in machine learning models because standard learners often exhibit bias towards the majority class. They prioritize minimizing global quantities like error rates without considering the underlying data distribution. Consequently, examples from the majority class are well-classified, while those from the minority class tend to be misclassified.
# <br>

# %% [markdown]
# 5.2 Use a technique to address class imbalance (e.g., oversampling, undersampling).
# 1. Load the prepared dataset
#
# 2. Identify if there is class imbalance issue via
#     - Calculating the distribution of each class of the target column.
#     - Displaying the discribution by pie chart.
#
# 3. Choose a technique to address class imbalance.

# %%
#Collect data by loading a CSV file from the current working directory
class_unbalanced_iris = pd.read_csv("Class_unbalanced_iris_data.csv")
class_unbalanced_iris.head(2)
# Out:
#    Unnamed: 0  sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0           0                 5.1                3.5                 1.4
# 1           1                 4.9                3.0                 1.4
#
#    petal_width_in_cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa

# %%
#calculate the distribution of each class of the target column
class_unbalanced_iris['class'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     28
# Iris-setosa        20
# Name: class, dtype: int64

# %%
#display pie chart
class_unbalanced_iris['class'].value_counts(normalize=True).plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='class'>

# %% [markdown]
# **<span style="color:blue;">Observations:</span>**
#
# We can see that the target column("class") has class imbalance issue. The percentage of the majority class("Iris-versicolor") is clearly different from the other two classes.
#
# Solution:
# The 'undersampling' technique will be employed to simplify, improve readability, and expedite the resolution of the class imbalance.

# %% [markdown]
# 5.3 Implement the technique using an appropriate Python package.

# %%
from imblearn.under_sampling import RandomUnderSampler

#Create an undersampler
undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)

#Create features (X) and target variable (y)
X = class_unbalanced_iris.drop(columns=['class'])
y = class_unbalanced_iris['class']

#Employ undersampling
X_resampled, y_resampled = undersampler.fit_resample(X, y)

#Create a new DataFrame with the resampled data
iris_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

#Displaying the discribution after undersampling by pie chart.
iris_resampled['class'].value_counts()
# Out:
# Iris-setosa        20
# Iris-versicolor    20
# Iris-virginica     20
# Name: class, dtype: int64

# %% [markdown]
# **<span style="color:blue;">Observations:</span>**
#
# We can see that some instances of "Iris-versicolor" and "Iris-virginice" have been randomly removed so that all three classes have the same size.
